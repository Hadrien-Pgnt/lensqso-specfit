# %%
# %load_ext autoreload
# %autoreload 2

import sys, os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import corner

sys.path.append('/local/hpaugnat/lensqso-specfit')

from spectrum_model import QuasarSpectrum
from multi_spectrum import MultiSpectrum
from multi_spec_fitter import Optimizer, PSO, MCMCSampler, FittingSequence
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
kwargs_model = {

    ## declare 'powerlaw' or ('polynomial', degree) for the continuum
    'continuum': 'powerlaw',
    
    ## declare a list of (name, type, degree) for the narrow doublets (type = 'Voigt' or 'GaussHermite') - 
    ## /!\ the doublet name must be in the dictionary QSO_narrow_doublets in QSO_spectral_features.py
    'narrow_doublets': [('OIII', 'GaussHermite', 5)], 


    ## declare a list of (name, type, degree, 'broad'/'narrow') for individual lines (type = 'Voigt' or 'GaussHermite')
    ## name must either be one of the keys in the dictionary QSO_single_lines in QSO_spectral_features.py, or a a float representing the rest-frame wavelength in Angstroms
    'single_lines': [('Hbeta', 'GaussHermite', 5, 'broad'), 
                     #('Hbeta', 'Voigt', None, 'narrow'),
                     #(4862.7, 'GaussHermite', 5, 'broad'), 
                    ],

    ## declare template lines (only 'FeII_Vis' and 'FeII+MgII_NIR' available for now) 
    'Template_lines': ['FeII_Vis'],
}

# %%
## declare the data (dictonary of the form {image_name : [wavelength, flux, flux_err]})
kwargs_data = {}
for image_name in ['A', 'B', 'C', 'D']:
    data = np.load('example_spectrum_'+image_name+'.npy')
    data[2][data[2]<5e-3] = 5e-3 #some points have underestimated error
    kwargs_data[image_name] = data


## declare the parameters that are fixed between images
kwargs_fixed = {'ref_image': 'A', 
                'fixed_params':{'OIII_narrow_doublet':['dlam', 'width', 'relcoeffsHermite'],
                                'Hbeta_broad':[],
                                #'Hbeta_narrow':['dlam', 'width'],
                               'FeII_Vis_template': ['dlam', 'velocity', 'relG', 'relIZw1', 'relS']
                               }}

## instantiate the MultiSpectrum() class 
qso_spec = MultiSpectrum(kwargs_data=kwargs_data, kwargs_model=kwargs_model, kwargs_fixed=kwargs_fixed)
print(qso_spec.param_handler.free_nonlinear_param_list)
#print(qso_spec.param_handler.kwargs_nonlinear_mult)


## change the priors on some parameters (prior=[mean, std dev, lower bound, upper bound]) for a list of chosen images (use images='all' to update prior for all images).
qso_spec.set_priors('continuum', {'beta':[0,0.1,-1,1]}, images='all')
qso_spec.set_priors('OIII_narrow_doublet', {'width':[5,0.1,0,10], 'dlam':[5,1,-10,15]}, images=['A'])
qso_spec.set_priors('Hbeta_broad', {'width':[40, 7.5, 10, 80]}, images='all')
qso_spec.set_priors('Hbeta_broad', {'dlam':[1, 1, -40, 40]}, images=['A'])

## initialize parameter values with the mean from each prior 
qso_spec.set_initial_values()

#array = qso_spec.param_handler.kwargs_nonlinear2array()
#print(array)
#print(qso_spec.param_handler.array2kwargs_nonlinear(array))
#print(qso_spec.param_handler.kwargs_nonlinear_mult)
#print(qso_spec.get_bounds_free_nonlinear_params())
# Out:
# ['continuum_beta_A', 'OIII_narrow_doublet_dlam_A', 'OIII_narrow_doublet_width_A', 'OIII_narrow_doublet_relcoeffsHermite1_A', 'OIII_narrow_doublet_relcoeffsHermite2_A', 'OIII_narrow_doublet_relcoeffsHermite3_A', 'OIII_narrow_doublet_relcoeffsHermite4_A', 'OIII_narrow_doublet_relcoeffsHermite5_A', 'Hbeta_broad_dlam_A', 'Hbeta_broad_width_A', 'FeII_Vis_template_dlam_A', 'FeII_Vis_template_velocity_A', 'FeII_Vis_template_relG_A', 'FeII_Vis_template_relIZw1_A', 'FeII_Vis_template_relS_A', 'continuum_beta_B', 'Hbeta_broad_dlam_B', 'Hbeta_broad_width_B', 'continuum_beta_C', 'Hbeta_broad_dlam_C', 'Hbeta_broad_width_C', 'continuum_beta_D', 'Hbeta_broad_dlam_D', 'Hbeta_broad_width_D']

# %%
## simulate spectra based on the initial parameter values, and return the likelihood
tol_positive=-3e-2 #consider a flux as positive above this value (likelihood will be -np.inf if one spectral component has negative flux somewhere)
logL, kwargs_values = qso_spec.log_likelihood_from_kwargs(tol_positive=tol_positive)
simulated_flux = qso_spec.simulateSpectra(kwargs_values, plot=True, tol_positive=tol_positive)
print('Log-likelihood:', logL)
# Out:
# Log-likelihood: -376.23660617188347

# %%
## Define custom masks to remove some points from the fit if there are artifacts.

mask_B = 1- (kwargs_data[image_name][0] > 4710) * (kwargs_data[image_name][0] < 4730)
mask_B *= 1- (kwargs_data[image_name][0] > 5150) * (kwargs_data[image_name][0] < 5185) 

mask_D = 1- (kwargs_data[image_name][0] > 4837) * (kwargs_data[image_name][0] < 4847)

# %%
## Define  arguments for the likelihood (masks & tolerance for negative fluxes)
kwargs_likelihood = {'mask_dict':{'B': mask_B, 'D': mask_D},
                     'tol_positive': -3e-2} #consider a flux as positive above this value (likelihood will be -np.inf if one spectral component has negative flux somewhere)

## Define the steps in the fitting sequence 
fit_param_list = [('PSO', {'n_particles':100, 'max_iter':1000}),
                  ('update_kwargs_likelihood', {'tol_positive': -2e-3}),
                  ('MCMC', {'n_walkers':100, 'n_run':1000, 'n_burn':100, 'skip_initial_state_check':True})
                 ]

## Instantiate and run the fitting sequence, then plot convergence and outputs
fitting_seq = FittingSequence(fit_param_list, qso_spec, kwargs_likelihood)
chain_seq = fitting_seq.run_sequence()
fitting_seq.plot_convergence()
fitting_seq.get_kwargs_values_best(plot=True)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [05:22<00:00,  3.10it/s]
# Max iteration reached! Stopping.
# Time taken for PSO optimization:  322.0809557437897
# Computing the MCMC...
# Number of walkers:  100
# Burn-in iterations:  100
# Sampling iterations (in current run): 1100
#   0%|                                                                                                                                    | 0/1100 [00:00<?, ?it/s]/home/hpaugnat/anaconda3/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1100/1100 [07:46<00:00,  2.36it/s]
# /local/hpaugnat/lensqso-specfit/multi_spec_fitter.py:205: RuntimeWarning: invalid value encountered in subtract
#   dist_normed = (dist_averaged - np.nanmax(dist_averaged)) / (
# /local/hpaugnat/lensqso-specfit/multi_spec_fitter.py:202: RuntimeWarning: invalid value encountered in divide
#   samples_renormed = (samples_averaged - end_point) / np.std(samples_averaged)
# Time taken for MCMC sampling:  467.1995792388916
# For image A:
# Normalized residuals have mean 0.00 and std dev 0.20
# For image B:
# Normalized residuals have mean 0.02 and std dev 0.38
# For image C:
# Normalized residuals have mean 0.01 and std dev 0.29
# For image D:
# Normalized residuals have mean 0.00 and std dev 0.20
# {'A': {'continuum': {'beta': 0.9523901005360611, 'amp': 0.10002333102915119},
#   'OIII_narrow_doublet': {'dlam': 5.7562659720598806,
#    'width': 5.73703878599835,
#    'relcoeffsHermite': array([-0.25942804,  0.1586742 , -0.04018882,  0.02907749, -0.00382542]),
#    'amp': 0.476884140726417},
#   'Hbeta_broad': {'dlam': -4.221953179431793,
#    'width': 39.01277785796468,
#    'coeffsHermite': array([7.80609521, 4.25709455, 1.28820624, 1.09359597, 0.12801308,
#           0.10204074])},
#   'FeII_Vis_template': {'dlam': 14.71099288925253,
#    'velocity': 1547.1865048667432,
#    'relG': 0.9291815245096369,
#    'relIZw1': 0.6988164990466363,
#    'relS': 0.6050187338881441,
#    'F': 0.23296390055855187}},
#  'B': {'continuum': {'beta': 0.09793116606938872, 'amp': 0.12782326318254225},
#   'OIII_narrow_doublet': {'dlam': 5.7562659720598806,
#    'width': 5.73703878599835,
#    'relcoeffsHermite': array([-0.25942804,  0.1586742 , -0.04018882,  0.02907749, -0.00382542]),
#    'amp': 0.5385091960995612},
#   'Hbeta_broad': {'dlam': 11.892699119197408,
#    'width': 79.9999270788862,
#    'coeffsHermite': array([12.13848585,  2.21269582,  3.01619289,  1.41399178,  0.75181856,
#            0.1522124 ])},
#   'FeII_Vis_template': {'dlam': 14.71099288925253,
#    'velocity': 1547.1865048667432,
#    'relG': 0.9291815245096369,
#    'relIZw1': 0.6988164990466363,
#    'relS': 0.6050187338881441,
#    'F': 0.3446306336035195}},
#  'C': {'continuum': {'beta': 0.9657538876278305, 'amp': 0.09432231245624147},
#   'OIII_narrow_doublet': {'dlam': 5.7562659720598806,
#    'width': 5.73703878599835,
#    'relcoeffsHermite': array([-0.25942804,  0.1586742 , -0.04018882,  0.02907749, -0.00382542]),
#    'amp': 0.4125050040931228},
#   'Hbeta_broad': {'dlam': 2.295354750172785,
#    'width': 40.791959687443644,
#    'coeffsHermite': array([6.97059695, 0.91341888, 0.50789649, 0.40043143, 0.10808707,
#           0.05754902])},
#   'FeII_Vis_template': {'dlam': 14.71099288925253,
#    'velocity': 1547.1865048667432,
#    'relG': 0.9291815245096369,
#    'relIZw1': 0.6988164990466363,
#    'relS': 0.6050187338881441,
#    'F': 0.14988344588944003}},
#  'D': {'continuum': {'beta': 0.9999853448646681, 'amp': 0.06602364328069359},
#   'OIII_narrow_doublet': {'dlam': 5.7562659720598806,
#    'width': 5.73703878599835,
#    'relcoeffsHermite': array([-0.25942804,  0.1586742 , -0.04018882,  0.02907749, -0.00382542]),
#    'amp': 0.27288934884251753},
#   'Hbeta_broad': {'dlam': 39.9986440758202,
#    'width': 50.33426399198082,
#    'coeffsHermite': array([ 4.87125912, -1.67129735,  0.74779642, -0.52761834,  0.09039255,
#           -0.06695394])},
#   'FeII_Vis_template': {'dlam': 14.71099288925253,
#    'velocity': 1547.1865048667432,
#    'relG': 0.9291815245096369,
#    'relIZw1': 0.6988164990466363,
#    'relS': 0.6050187338881441,
#    'F': 0.12959938922089304}}}

# %%
## Compute & plot the posterior distribution of flux ratios
mcmc_sampler = MCMCSampler(qso_spec, kwargs_likelihood=kwargs_likelihood)
mcmc_sampler.samples_mcmc = chain_seq[1][3]
narrow_doublet_fluxratios_post, fr_names = mcmc_sampler.narrow_doublet_flux_ratio_posterior('OIII', n_samples=2000, n_burn_add=500)
print(fr_names)

figure = corner.corner(narrow_doublet_fluxratios_post, labels=list(fr_names),
    quantiles=[0.16, 0.5, 0.84], show_titles=True, title_kwargs={"fontsize": 12})
# Out:
# ['f_B/f_A', 'f_C/f_A', 'f_D/f_A']

# %%
kwargs_likelihood = {'mask_dict':{'B': mask_B, 'D': mask_D},
                     'tol_positive': -3e-2} #consider a flux as positive above this value (likelihood will be -np.inf if one spectral component has negative flux somewhere)

## Run a single optimization step (here a PSO) instead of a full fitting sequence
opt = PSO(qso_spec, n_particles=100, kwargs_likelihood=kwargs_likelihood)
logL, kwargs_values = opt.optimize(max_iter=1000, plot=True)
#simulated_flux = qso_spec.simulateSpectra(kwargs_values, plot=True)

print('Best-fitting parameters: ', kwargs_values)
print('Log-likelihood: ', logL)
print('Number of free (non-linear) parameters: ', len(qso_spec.param_handler.free_nonlinear_param_list))
print('Number of free (linear + non-linear) parameters: ', qso_spec.param_handler.nb_free_params)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [05:41<00:00,  2.93it/s]
# Max iteration reached! Stopping.
# Time taken for PSO optimization:  341.38907408714294
# For image A:
# Normalized residuals have mean 0.00 and std dev 0.20
# For image B:
# Normalized residuals have mean 0.02 and std dev 0.38
# For image C:
# Normalized residuals have mean 0.01 and std dev 0.29
# For image D:
# Normalized residuals have mean 0.00 and std dev 0.23
# Best-fitting parameters:  {'A': {'continuum': {'beta': 0.8204880909667424, 'amp': 0.10060326281606445}, 'OIII_narrow_doublet': {'dlam': 3.498888945635431, 'width': 5.52477508045093, 'relcoeffsHermite': array([ 0.01819926,  0.11137078, -0.00570946,  0.02044912,  0.00343873]), 'amp': 0.4621159409323519}, 'Hbeta_broad': {'dlam': -4.9583627275585505, 'width': 39.40545824456012, 'coeffsHermite': array([7.66555241, 4.53507977, 1.2089513 , 1.18181165, 0.11904921,
#        0.10887363])}, 'FeII_Vis_template': {'dlam': 13.752311502541543, 'velocity': 1558.3453494598423, 'relG': 1.2613536831862797, 'relIZw1': 0.6372518056820176, 'relS': 0.5997169060379774, 'F': 0.2265920872843199}}, 'B': {'continuum': {'beta': 0.022823802857149994, 'amp': 0.12570950741424103}, 'OIII_narrow_doublet': {'dlam': 3.498888945635431, 'width': 5.52477508045093, 'relcoeffsHermite': array([ 0.01819926,  0.11137078, -0.00570946,  0.02044912,  0.00343873]), 'amp': 0.5195896837745995}, 'Hbeta_broad': {'dlam': 39.9832359494037, 'width': 79.99354176354159, 'coeffsHermite': array([13.5636631 , -1.04101827,  4.22271711,  0.35868299,  0.77305854,
#        -0.06181973])}, 'FeII_Vis_template': {'dlam': 13.752311502541543, 'velocity': 1558.3453494598423, 'relG': 1.2613536831862797, 'relIZw1': 0.6372518056820176, 'relS': 0.5997169060379774, 'F': 0.3467719098525659}}, 'C': {'continuum': {'beta': 0.8879797794845443, 'amp': 0.09454237810842431}, 'OIII_narrow_doublet': {'dlam': 3.498888945635431, 'width': 5.52477508045093, 'relcoeffsHermite': array([ 0.01819926,  0.11137078, -0.00570946,  0.02044912,  0.00343873]), 'amp': 0.3989777496962623}, 'Hbeta_broad': {'dlam': 1.8579088618500592, 'width': 41.31879374464286, 'coeffsHermite': array([6.93712451, 1.11196326, 0.47905863, 0.47348488, 0.10903412,
#        0.06335067])}, 'FeII_Vis_template': {'dlam': 13.752311502541543, 'velocity': 1558.3453494598423, 'relG': 1.2613536831862797, 'relIZw1': 0.6372518056820176, 'relS': 0.5997169060379774, 'F': 0.14945081943524383}}, 'D': {'continuum': {'beta': 0.0787254733157438, 'amp': 0.06881960868303907}, 'OIII_narrow_doublet': {'dlam': 3.498888945635431, 'width': 5.52477508045093, 'relcoeffsHermite': array([ 0.01819926,  0.11137078, -0.00570946,  0.02044912,  0.00343873]), 'amp': 0.26235542949754936}, 'Hbeta_broad': {'dlam': -10.701424020009208, 'width': 54.03595529806059, 'coeffsHermite': array([3.93587197e+00, 3.18777101e+00, 2.59570939e-01, 7.64679035e-01,
#        4.95021710e-04, 8.09503487e-02])}, 'FeII_Vis_template': {'dlam': 13.752311502541543, 'velocity': 1558.3453494598423, 'relG': 1.2613536831862797, 'relIZw1': 0.6372518056820176, 'relS': 0.5997169060379774, 'F': 0.0854934213898009}}}
# Log-likelihood:  -152.20230821720637
# Number of free (non-linear) parameters:  24
# Number of free (linear + non-linear) parameters:  60

# %%
## Get flux ratios for best-fitting model
for image in ['A', 'B', 'C', 'D']:
    print(kwargs_values[image]['OIII_narrow_doublet']['amp']/kwargs_values['A']['OIII_narrow_doublet']['amp'])
# Out:
# 1.0
# 1.1299851362166697
# 0.8636378151951278
# 0.5704021899951781

# %% [markdown]
# ## Testing

# %%
data = np.load('example_spectrum_A.npy')
data[2][data[2]<5e-3] = 5e-3 #some points have understimated error
print(np.average(data[1], weights=1/data[2]**2))
qso_1spec = QuasarSpectrum(data, kwargs_model, narrow_doublet_relHerm=['OIII'])

kwargs_nonlinear = {'continuum': {'beta':0},
                    'OIII_narrow_doublet': {'width':6.3, 'dlam':5, 
                                            'relcoeffsHermite': np.array([0.01, 0.01, 0.])
                                            },
                    'Hbeta_broad':{'width':30, 'dlam':10},
                    #'Hbeta_narrow':{'width':5, 'dlam':10, 'gamma':5},
                    'FeII_Vis_template':{'dlam':10, 'velocity':3700}
                   }

fig, axes = plt.subplots(2,1, height_ratios=[5,2], figsize=(10, 7))
#print(qso_1spec.make_transposed_response_matrix(kwargs_nonlinear))
print(qso_1spec.lin_param_handler.linear_param_list)
print(qso_1spec.log_likelihood(kwargs_nonlinear, plot_axes=axes))
# Out:
# 0.11791396609360962
# ['continuum_amp', 'OIII_narrow_doublet_amp', 'Hbeta_broad_coeffsHermite0', 'Hbeta_broad_coeffsHermite1', 'Hbeta_broad_coeffsHermite2', 'Hbeta_broad_coeffsHermite3', 'Hbeta_broad_coeffsHermite4', 'Hbeta_broad_coeffsHermite5', 'FeII_Vis_template_F', 'FeII_Vis_template_G', 'FeII_Vis_template_IZw1', 'FeII_Vis_template_S']
# (-47.563325758492574, {'continuum': {'beta': 0, 'amp': 0.09161517984957264}, 'OIII_narrow_doublet': {'width': 6.3, 'dlam': 5, 'relcoeffsHermite': array([0.01, 0.01, 0.  ]), 'amp': 0.43440562888445755}, 'Hbeta_broad': {'width': 30, 'dlam': 10, 'coeffsHermite': array([8.17226979e+00, 6.55380272e-01, 2.56587772e+00, 1.78857845e-01,
#        2.88141118e-01, 7.63151734e-03])}, 'FeII_Vis_template': {'dlam': 10, 'velocity': 3700, 'F': 0.2619076499305934, 'G': 0.3153489727440998, 'IZw1': 0.22615917510866337, 'S': 0.5158571767648118}})

# %%
from QSO_spectral_features import FeIIMgII_NIR_TemplateLines
lamRest = np.linspace(8900, 10000, 1000)

template = FeIIMgII_NIR_TemplateLines()
plt.plot(lamRest, template.make_flux(lamRest, amp=1.0, dlam=0., dispVel=500))
#lines = np.array([6400,6450, 6125])
#weights = np.array([1,0.5, 0.1])
#linelambdas = np.expand_dims(lines, axis=1)
#vel_disp = 500
#c = 3e5
#sigma_lambda = vel_disp*(linelambdas)/c
#lamNorm = (np.tile(lamRest, (len(lines), 1)) - linelambdas)/ (np.sqrt(2)*sigma_lambda)
#spectrum = np.exp(-lamNorm**2)/(np.sqrt(2*np.pi)*sigma_lambda)
#plt.plot(lamRest, np.dot(weights, spectrum))
